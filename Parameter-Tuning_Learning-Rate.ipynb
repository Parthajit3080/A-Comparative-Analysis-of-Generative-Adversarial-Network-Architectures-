# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torchvision.utils import save_image
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import numpy as np
import matplotlib.pyplot as plt
import torchvision.utils as vutils
import os
from torchvision.models import inception_v3
from scipy.linalg import sqrtm
from torchsummary import summary as Summary

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

latent_dim = 100
batch_size = 64
img_shape = (3, 32, 32)
n_epochs = 50
n_critic = 5
c = 0.01

print(device)
# Out:
# cuda

# %%
# Load Inception-v3 in eval mode
inception = inception_v3(pretrained=True, transform_input=False)
inception.fc = torch.nn.Identity()  # Remove final classification layer
inception.aux_logits = False
inception.eval()

if torch.cuda.is_available():
    inception = inception.cuda()
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=Inception_V3_Weights.IMAGENET1K_V1`. You can also use `weights=Inception_V3_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/inception_v3_google-0cc3c7bd.pth" to /root/.cache/torch/hub/checkpoints/inception_v3_google-0cc3c7bd.pth
# 100%|██████████| 104M/104M [00:00<00:00, 224MB/s]

# %%
def preprocess_images(images):
    """Preprocess images for Inception-v3"""
    # Ensure images are in [0, 1] range
    if images.min() >= -1.0 and images.max() <= 1.0:
        # Input is in [-1, 1] range (GAN output)
        images = (images + 1.0) / 2.0
    elif images.max() > 1.0:
        # Input is in [0, 255] range
        images = images / 255.0
    else:
        # Already in [0, 1] range
        pass
    
    # Clamp to [0, 1]
    images = torch.clamp(images, 0.0, 1.0)
    
    # Resize to 299x299
    images = F.interpolate(images, size=(299, 299), mode='bilinear', align_corners=False)
    
    # ImageNet normalization
    mean = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1)
    
    if images.is_cuda:
        mean = mean.cuda()
        std = std.cuda()
    
    images = (images - mean) / std
    return images

# %%
def get_features(images, model):
    """Extract features using Inception-v3 (2048D from pool3 layer)"""
    model.eval()
    with torch.no_grad():
        if torch.cuda.is_available():
            images = images.cuda()
            
        # Preprocess images properly
        images = preprocess_images(images)
        
        # Use the standard forward pass to get pool3 features (2048D)
        # This automatically handles all the layers correctly
        features = model(images)  # This gives us the final pooled features
        
        # If features are still 2D (batch_size, features), we're good
        # If they're 4D, we need to pool them
        if len(features.shape) == 4:
            features = F.adaptive_avg_pool2d(features, (1, 1))
            features = torch.flatten(features, 1)
    
    return features.cpu()

# %%
def calculate_stats(features):
    """Calculate mean and covariance matrix"""
    features = features.numpy().astype(np.float64)  # Use float64 for numerical stability
    mu = np.mean(features, axis=0)
    sigma = np.cov(features, rowvar=False)
    return mu, sigma

# %%
def calculate_fid(mu1, sigma1, mu2, sigma2, eps=1e-6):
    """Calculate FID score"""
    mu1 = np.atleast_1d(mu1)
    mu2 = np.atleast_1d(mu2)
    
    sigma1 = np.atleast_2d(sigma1)
    sigma2 = np.atleast_2d(sigma2)
    
    # Ensure matrices are symmetric (numerical stability)
    sigma1 = (sigma1 + sigma1.T) / 2
    sigma2 = (sigma2 + sigma2.T) / 2
    
    # Add small epsilon to diagonal for numerical stability
    sigma1 += eps * np.eye(sigma1.shape[0])
    sigma2 += eps * np.eye(sigma2.shape[0])
    
    diff = mu1 - mu2
    
    # Calculate sqrt of product of covariance matrices
    try:
        covmean, _ = sqrtm(sigma1.dot(sigma2), disp=False)
    except Exception as e:
        print(f"Error in sqrtm: {e}")
        # Fallback: add more regularization
        sigma1 += eps * 10 * np.eye(sigma1.shape[0])
        sigma2 += eps * 10 * np.eye(sigma2.shape[0])
        covmean, _ = sqrtm(sigma1.dot(sigma2), disp=False)
    
    # Handle numerical errors in sqrtm
    if np.iscomplexobj(covmean):
        if not np.allclose(np.diagonal(covmean).imag, 0, atol=1e-3):
            m = np.max(np.absolute(covmean.imag))
            raise ValueError(f"Imaginary component {m}")
        covmean = covmean.real
    
    fid = diff.dot(diff) + np.trace(sigma1 + sigma2 - 2 * covmean)
    return fid

# %%
def compute_fid(real_images, fake_images, batch_size=64):
    """Compute FID between real and fake images"""
    # Create data loaders
    real_loader = DataLoader(real_images, batch_size=batch_size, shuffle=False)
    fake_loader = DataLoader(fake_images, batch_size=batch_size, shuffle=False)
    
    # Process real images
    real_features = []
    for batch in real_loader:
        real_features.append(get_features(batch, inception))
    real_features = torch.cat(real_features, dim=0)

    # Process fake images
    fake_features = []
    for batch in fake_loader:
        fake_features.append(get_features(batch, inception))
    fake_features = torch.cat(fake_features, dim=0)

    # Calculate statistics
    mu_real, sigma_real = calculate_stats(real_features)
    mu_fake, sigma_fake = calculate_stats(fake_features)

    return calculate_fid(mu_real, sigma_real, mu_fake, sigma_fake)

# %%
def evaluate_fid(generator, dataloader, sample_size, batch_size_fid, latent_dim, device):
    """Evaluate FID score for a generator"""
    generator.eval()
    
    # Generate fake images
    fake_images = []
    with torch.no_grad():
        for j in range(0, sample_size, batch_size_fid):
            current_batch = min(batch_size_fid, sample_size - j)
            z = torch.randn(current_batch, latent_dim).to(device)
            fake_batch = generator(z).cpu()
            fake_images.append(fake_batch)
    fake_images = torch.cat(fake_images, dim=0)

    # Collect real images
    real_images = []
    total_collected = 0
    for imgs, _ in dataloader:
        real_images.append(imgs)
        total_collected += imgs.size(0)
        if total_collected >= sample_size:
            break
    
    real_images = torch.cat(real_images, dim=0)[:sample_size]
    
    # Ensure we have the same number of real and fake images
    min_size = min(len(real_images), len(fake_images))
    real_images = real_images[:min_size]
    fake_images = fake_images[:min_size]
    
    # Compute FID
    fid = compute_fid(real_images, fake_images)
    
    generator.train()
    return fid

# %%
selected_classes = [2,3,4,5,6,7]

class CIFAR10Subset(Dataset):
    def __init__(self, root, train=True, selected_labels=None, transform=None):
        self.full_dataset = datasets.CIFAR10(root=root, train=train, transform=transform, download=True)
        self.selected_labels = selected_labels if selected_labels is not None else list(range(10))
        self.indices = [i for i, (_, label) in enumerate(self.full_dataset) if label in self.selected_labels]

    def __len__(self):
        return len(self.indices)

    def __getitem__(self, idx):
        true_idx = self.indices[idx]
        img, label = self.full_dataset[true_idx]
        return img, label

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
])

subset = CIFAR10Subset(root='./data', train=True, selected_labels=selected_classes, transform=transform)
dataloader = DataLoader(subset, batch_size=64, shuffle=True)
# Out:
# 100%|██████████| 170M/170M [00:05<00:00, 29.1MB/s]

# %%
class Generator(nn.Module):
    def __init__(self, latent_dim):
        super().__init__()

        self.model = nn.Sequential(
            nn.Linear(latent_dim, 128 * 8 * 8),
            nn.ReLU(),
            nn.Unflatten(1, (128, 8, 8)),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128, momentum=0.78),
            nn.ReLU(),
            nn.Upsample(scale_factor=2),
            nn.Conv2d(128, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64, momentum=0.78),
            nn.ReLU(),
            nn.Conv2d(64, 3, kernel_size=3, padding=1),
            nn.Tanh()
        )

    def forward(self, z):
        img = self.model(z)
        return img

generator = Generator(latent_dim).to(device)
print(Summary(generator, input_size=(latent_dim,), batch_size=batch_size, device="cuda"))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                 [64, 8192]         827,392
#               ReLU-2                 [64, 8192]               0
#          Unflatten-3            [64, 128, 8, 8]               0
#           Upsample-4          [64, 128, 16, 16]               0
#             Conv2d-5          [64, 128, 16, 16]         147,584
#        BatchNorm2d-6          [64, 128, 16, 16]             256
#               ReLU-7          [64, 128, 16, 16]               0
#           Upsample-8          [64, 128, 32, 32]               0
#             Conv2d-9           [64, 64, 32, 32]          73,792
#       BatchNorm2d-10           [64, 64, 32, 32]             128
#              ReLU-11           [64, 64, 32, 32]               0
#            Conv2d-12            [64, 3, 32, 32]           1,731
#              Tanh-13            [64, 3, 32, 32]               0
# ================================================================
# Total params: 1,050,883
# Trainable params: 1,050,883
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.02
# Forward/backward pass size (MB): 239.00
# Params size (MB): 4.01
# Estimated Total Size (MB): 243.03
# ----------------------------------------------------------------
# None

# %%
class Critic(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.model = nn.Sequential(
            # Input: 3 x 32 x 32
            nn.Conv2d(3, 128, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            # 64 x 16 x 16
            
            nn.Conv2d(128,256 , kernel_size=4, stride=2, padding=1, bias=False),
            nn.LayerNorm([256, 8, 8]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            # 128 x 8 x 8
            
            nn.Conv2d(256,512, kernel_size=4, stride=2, padding=1, bias=False),
            nn.LayerNorm([512,4,4]),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Dropout2d(0.2),
            # 256 x 4 x 4
            
            # Global average pooling instead of another conv layer
            nn.AdaptiveAvgPool2d(1),  # 256 x 1 x 1
            nn.Flatten(),
            nn.Linear(512, 1)
        )

    def forward(self, x):
        return self.model(x)

critic = Critic().to(device)
print(Summary(critic, (3, 32, 32)))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 128, 16, 16]           6,144
#          LeakyReLU-2          [-1, 128, 16, 16]               0
#          Dropout2d-3          [-1, 128, 16, 16]               0
#             Conv2d-4            [-1, 256, 8, 8]         524,288
#          LayerNorm-5            [-1, 256, 8, 8]          32,768
#          LeakyReLU-6            [-1, 256, 8, 8]               0
#          Dropout2d-7            [-1, 256, 8, 8]               0
#             Conv2d-8            [-1, 512, 4, 4]       2,097,152
#          LayerNorm-9            [-1, 512, 4, 4]          16,384
#         LeakyReLU-10            [-1, 512, 4, 4]               0
#         Dropout2d-11            [-1, 512, 4, 4]               0
# AdaptiveAvgPool2d-12            [-1, 512, 1, 1]               0
#           Flatten-13                  [-1, 512]               0
#            Linear-14                    [-1, 1]             513
# ================================================================
# Total params: 2,677,249
# Trainable params: 2,677,249
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 1.51
# Params size (MB): 10.21
# Estimated Total Size (MB): 11.73
# ----------------------------------------------------------------
# None

# %%
def show_imgs(real_imgs, gen_imgs, n=10):
    """Display real and generated images side by side"""
    n = min(n, len(real_imgs), len(gen_imgs))  # Ensure we don't exceed available images
    
    real = real_imgs[:n].cpu().detach()
    fake = gen_imgs[:n].cpu().detach()

    # Rescale from [-1, 1] to [0, 1]
    real = (real + 1) / 2
    fake = (fake + 1) / 2

    fig, axes = plt.subplots(2, n, figsize=(2*n, 4))
    
    # Handle case where n=1 (axes won't be 2D)
    if n == 1:
        axes = axes.reshape(2, 1)

    for i in range(n):
        # Real images on top row
        real_img = real[i].permute(1, 2, 0).numpy()
        axes[0, i].imshow(real_img, vmin=0, vmax=1)
        axes[0, i].axis("off")
        if i == 0:
            axes[0, i].set_title("Real Images")

        # Fake images on bottom row
        fake_img = fake[i].permute(1, 2, 0).numpy()
        axes[1, i].imshow(fake_img, vmin=0, vmax=1)
        axes[1, i].axis("off")
        if i == 0:
            axes[1, i].set_title("Generated Images")

    plt.tight_layout()
    plt.show()

# %%
def train_WGAN(generator, critic, optimizer_g, optimizer_c, dataloader, device, latent_dim, n_critic , c , n_epochs , fid_0):
    os.makedirs("images_WGAN", exist_ok=True)

    g_losses = []  
    c_losses = []
    fid_scores = []
    fid_scores.append(fid_0)  # Adding the fid value of noise genertaed by the generator before Training 

    for epoch in range(1 , n_epochs+1):
        g_loss_epoch = 0.0  # Intialised the loss variables 
        c_loss_epoch = 0.0
        batches = 0
        
        for i, (imgs, _) in enumerate(dataloader): 
            real_imgs = imgs.to(device)
            batches += 1
            c_loss_n = 0.0
            b_size = imgs.size(0)  # to track the current batch size

            for _ in range(n_critic):
                optimizer_c.zero_grad()
 
                z = torch.randn(b_size, latent_dim).to(device)
                fake_imgs = generator(z).detach()

                real_validity = critic(real_imgs)
                fake_validity = critic(fake_imgs)

                loss_c = - (torch.mean(real_validity) - torch.mean(fake_validity))   # loss of Critic = max ( E(D(x)) - E(G(z)) )
                c_loss_n += loss_c.item()                                            # maximising the loss = minimising the the -ve of loss as optimizers are used to reduce the loss values 
                loss_c.backward()                                                                   
                optimizer_c.step()

                for p in critic.parameters():           # Weight Clipping 
                    p.data.clamp_(-c, c)

            c_loss_epoch += (c_loss_n / n_critic)   # taking Avg of all the losses for n_critic

            optimizer_g.zero_grad()
            z = torch.randn(b_size, latent_dim).to(device)
            gen_imgs = generator(z)
            gen_validity = critic(gen_imgs)
            loss_g = - torch.mean(gen_validity)   # loss of Generator = min( - E(D(G(z))) ) 
            g_loss_epoch += loss_g.item()         # and we will keep it as it is as optimisers are already doing this 
            loss_g.backward()
            optimizer_g.step()
            
        avg_c_loss = c_loss_epoch / batches
        avg_g_loss = g_loss_epoch / batches

        g_losses.append(avg_g_loss)
        c_losses.append(avg_c_loss)
        
        fid_score = evaluate_fid(generator, dataloader, 5000 , 100 , latent_dim, device)  # Computing the FID in each epoch 
        fid_scores.append(fid_score)

        print(f"[Epoch {epoch}/{n_epochs}] Loss D: {avg_c_loss:.4f}, Loss G: {avg_g_loss:.4f} , FID score : {fid_score:.4f}")

        # Printing The Results for every 25th iteration

        if epoch % 25 == 0:
            noise = torch.randn(15,latent_dim).to(device)
            with torch.no_grad():
              gen_images = generator(noise).to(device)
            save_image(gen_images.data[:10], f"images_WGAN/{epoch}.png", nrow=5, normalize=True)
            show_imgs(real_imgs, gen_images, n=10)

    # Plotting The Curves 

    plt.figure(figsize=(10, 5))
    plt.plot(g_losses, label='Generator Loss')
    plt.plot(c_losses, label='Critic Loss')
    plt.xlabel("Epoch")
    plt.ylabel("Average Loss")
    plt.title("WGAN Loss per Epoch")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    plt.figure(figsize=(10, 5))
    plt.plot(fid_scores, label='FID Score')
    plt.xlabel("Epoch")
    plt.ylabel("FID")
    plt.title("FID Score per Epoch")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.show()
    
    return fid_scores

# %%
generator_1 = Generator(latent_dim).to(device)
critic_1 = Critic().to(device)
optimizer_g1 = optim.RMSprop(generator_1.parameters(), lr=1e-4)
optimizer_c1 = optim.RMSprop(critic_1.parameters(), lr=1e-4)


with torch.no_grad():
    noise = torch.randn(10, latent_dim).to(device)
    gen_imgs = generator_1(noise)

# Get real images for comparison
for imgs, _ in dataloader:
    real_imgs = imgs.to(device)
    break
print("Before Training...")
val = evaluate_fid(generator_1, dataloader, 5000 , 100 , latent_dim, device)
show_imgs(real_imgs, gen_imgs, n=10)
print(f" FID : {val}")
print("Training started...")

# Start training
fid_1 = train_WGAN(generator_1, critic_1, optimizer_g1, optimizer_c1, dataloader, device, latent_dim, n_critic , c , n_epochs , val)
# Out:
# Before Training...
#  FID : 424.3338018597361
# Training started...
# [Epoch 1/50] Loss D: -0.0393, Loss G: 0.0166 , FID score : 128.8028
# [Epoch 2/50] Loss D: -0.0442, Loss G: 0.0181 , FID score : 121.3263
# [Epoch 3/50] Loss D: -0.0390, Loss G: 0.0162 , FID score : 107.8081
# [Epoch 4/50] Loss D: -0.0358, Loss G: 0.0138 , FID score : 105.3016
# [Epoch 5/50] Loss D: -0.0344, Loss G: 0.0132 , FID score : 96.6435
# [Epoch 6/50] Loss D: -0.0326, Loss G: 0.0117 , FID score : 94.6739
# [Epoch 7/50] Loss D: -0.0311, Loss G: 0.0107 , FID score : 93.1080
# [Epoch 8/50] Loss D: -0.0300, Loss G: 0.0096 , FID score : 88.8009
# [Epoch 9/50] Loss D: -0.0289, Loss G: 0.0081 , FID score : 85.3023
# [Epoch 10/50] Loss D: -0.0280, Loss G: 0.0083 , FID score : 80.0851
# [Epoch 11/50] Loss D: -0.0272, Loss G: 0.0081 , FID score : 85.2006
# [Epoch 12/50] Loss D: -0.0263, Loss G: 0.0066 , FID score : 81.4922
# [Epoch 13/50] Loss D: -0.0254, Loss G: 0.0060 , FID score : 82.2121
# [Epoch 14/50] Loss D: -0.0246, Loss G: 0.0063 , FID score : 83.7555
# [Epoch 15/50] Loss D: -0.0238, Loss G: 0.0060 , FID score : 76.8236
# [Epoch 16/50] Loss D: -0.0232, Loss G: 0.0063 , FID score : 81.2011
# [Epoch 17/50] Loss D: -0.0224, Loss G: 0.0051 , FID score : 77.0157
# [Epoch 18/50] Loss D: -0.0218, Loss G: 0.0046 , FID score : 72.3810
# [Epoch 19/50] Loss D: -0.0211, Loss G: 0.0066 , FID score : 71.3064
# [Epoch 20/50] Loss D: -0.0203, Loss G: 0.0047 , FID score : 73.7623
# [Epoch 21/50] Loss D: -0.0198, Loss G: 0.0046 , FID score : 71.2214
# [Epoch 22/50] Loss D: -0.0192, Loss G: 0.0047 , FID score : 70.4742
# [Epoch 23/50] Loss D: -0.0187, Loss G: 0.0057 , FID score : 69.5860
# [Epoch 24/50] Loss D: -0.0183, Loss G: 0.0059 , FID score : 67.8134
# [Epoch 25/50] Loss D: -0.0178, Loss G: 0.0056 , FID score : 67.1612
# [Epoch 26/50] Loss D: -0.0172, Loss G: 0.0057 , FID score : 66.6048
# [Epoch 27/50] Loss D: -0.0168, Loss G: 0.0062 , FID score : 67.6569
# [Epoch 28/50] Loss D: -0.0166, Loss G: 0.0047 , FID score : 64.3095
# [Epoch 29/50] Loss D: -0.0160, Loss G: 0.0027 , FID score : 63.7307
# [Epoch 30/50] Loss D: -0.0155, Loss G: 0.0052 , FID score : 68.0888
# [Epoch 31/50] Loss D: -0.0153, Loss G: 0.0052 , FID score : 64.8068
# [Epoch 32/50] Loss D: -0.0150, Loss G: 0.0036 , FID score : 66.2819
# [Epoch 33/50] Loss D: -0.0147, Loss G: 0.0039 , FID score : 67.0222
# [Epoch 34/50] Loss D: -0.0141, Loss G: 0.0041 , FID score : 67.2708
# [Epoch 35/50] Loss D: -0.0138, Loss G: 0.0055 , FID score : 66.3489
# [Epoch 36/50] Loss D: -0.0132, Loss G: 0.0036 , FID score : 62.7786
# [Epoch 37/50] Loss D: -0.0128, Loss G: 0.0022 , FID score : 67.3410
# [Epoch 38/50] Loss D: -0.0120, Loss G: 0.0032 , FID score : 63.9652
# [Epoch 39/50] Loss D: -0.0117, Loss G: 0.0037 , FID score : 63.1987
# [Epoch 40/50] Loss D: -0.0108, Loss G: 0.0029 , FID score : 68.3786
# [Epoch 41/50] Loss D: -0.0103, Loss G: 0.0022 , FID score : 70.2522
# [Epoch 42/50] Loss D: -0.0086, Loss G: 0.0027 , FID score : 64.9301
# [Epoch 43/50] Loss D: -0.0068, Loss G: 0.0002 , FID score : 67.6679
# [Epoch 44/50] Loss D: -0.0045, Loss G: 0.0007 , FID score : 66.9828
# [Epoch 45/50] Loss D: -0.0030, Loss G: -0.0037 , FID score : 72.5904
# [Epoch 46/50] Loss D: -0.0020, Loss G: -0.0031 , FID score : 73.4008
# [Epoch 47/50] Loss D: -0.0021, Loss G: -0.0108 , FID score : 75.7180
# [Epoch 48/50] Loss D: -0.0019, Loss G: -0.0013 , FID score : 82.1901
# [Epoch 49/50] Loss D: -0.0020, Loss G: -0.0030 , FID score : 86.3186
# [Epoch 50/50] Loss D: -0.0021, Loss G: 0.0012 , FID score : 86.8125

# %%
generator_2 = Generator(latent_dim).to(device)
critic_2 = Critic().to(device)
optimizer_g2 = optim.RMSprop(generator_2.parameters(), lr=1e-5)
optimizer_c2 = optim.RMSprop(critic_2.parameters(), lr=1e-5)


with torch.no_grad():
    noise = torch.randn(10, latent_dim).to(device)
    gen_imgs = generator_2(noise)

# Get real images for comparison
for imgs, _ in dataloader:
    real_imgs = imgs.to(device)
    break
print("Before Training...")
val = evaluate_fid(generator_2, dataloader, 5000 , 100 , latent_dim, device)
show_imgs(real_imgs, gen_imgs, n=10)
print(f" FID : {val}")
print("Training started...")

# Start training
fid_2 = train_WGAN(generator_2, critic_2, optimizer_g2, optimizer_c2, dataloader, device, latent_dim, n_critic , c , n_epochs , val)
# Out:
# Before Training...
#  FID : 404.1722985815388
# Training started...
# [Epoch 1/50] Loss D: -0.0640, Loss G: 0.0329 , FID score : 319.5608
# [Epoch 2/50] Loss D: -0.0898, Loss G: 0.0446 , FID score : 274.3379
# [Epoch 3/50] Loss D: -0.0860, Loss G: 0.0433 , FID score : 252.2137
# [Epoch 4/50] Loss D: -0.0699, Loss G: 0.0375 , FID score : 238.9849
# [Epoch 5/50] Loss D: -0.0641, Loss G: 0.0351 , FID score : 208.1219
# [Epoch 6/50] Loss D: -0.0649, Loss G: 0.0347 , FID score : 183.4051
# [Epoch 7/50] Loss D: -0.0616, Loss G: 0.0330 , FID score : 167.0870
# [Epoch 8/50] Loss D: -0.0600, Loss G: 0.0320 , FID score : 161.6021
# [Epoch 9/50] Loss D: -0.0592, Loss G: 0.0316 , FID score : 155.9302
# [Epoch 10/50] Loss D: -0.0604, Loss G: 0.0319 , FID score : 151.9636
# [Epoch 11/50] Loss D: -0.0613, Loss G: 0.0325 , FID score : 143.6817
# [Epoch 12/50] Loss D: -0.0622, Loss G: 0.0330 , FID score : 138.2817
# [Epoch 13/50] Loss D: -0.0630, Loss G: 0.0335 , FID score : 135.6640
# [Epoch 14/50] Loss D: -0.0638, Loss G: 0.0339 , FID score : 134.4817
# [Epoch 15/50] Loss D: -0.0643, Loss G: 0.0339 , FID score : 130.7768
# [Epoch 16/50] Loss D: -0.0642, Loss G: 0.0338 , FID score : 128.6725
# [Epoch 17/50] Loss D: -0.0635, Loss G: 0.0337 , FID score : 124.6772
# [Epoch 18/50] Loss D: -0.0627, Loss G: 0.0332 , FID score : 125.0121
# [Epoch 19/50] Loss D: -0.0615, Loss G: 0.0325 , FID score : 118.7998
# [Epoch 20/50] Loss D: -0.0604, Loss G: 0.0321 , FID score : 117.1692
# [Epoch 21/50] Loss D: -0.0593, Loss G: 0.0314 , FID score : 107.9187
# [Epoch 22/50] Loss D: -0.0580, Loss G: 0.0308 , FID score : 106.8551
# [Epoch 23/50] Loss D: -0.0570, Loss G: 0.0302 , FID score : 107.3755
# [Epoch 24/50] Loss D: -0.0560, Loss G: 0.0297 , FID score : 103.4531
# [Epoch 25/50] Loss D: -0.0551, Loss G: 0.0292 , FID score : 104.6998
# [Epoch 26/50] Loss D: -0.0543, Loss G: 0.0288 , FID score : 102.5677
# [Epoch 27/50] Loss D: -0.0537, Loss G: 0.0286 , FID score : 99.9680
# [Epoch 28/50] Loss D: -0.0532, Loss G: 0.0285 , FID score : 100.3128
# [Epoch 29/50] Loss D: -0.0528, Loss G: 0.0282 , FID score : 98.0213
# [Epoch 30/50] Loss D: -0.0526, Loss G: 0.0281 , FID score : 89.9607
# [Epoch 31/50] Loss D: -0.0525, Loss G: 0.0282 , FID score : 99.4225
# [Epoch 32/50] Loss D: -0.0524, Loss G: 0.0282 , FID score : 91.6521
# [Epoch 33/50] Loss D: -0.0521, Loss G: 0.0278 , FID score : 99.1414
# [Epoch 34/50] Loss D: -0.0520, Loss G: 0.0277 , FID score : 92.6254
# [Epoch 35/50] Loss D: -0.0517, Loss G: 0.0280 , FID score : 95.1817
# [Epoch 36/50] Loss D: -0.0515, Loss G: 0.0277 , FID score : 90.8630
# [Epoch 37/50] Loss D: -0.0509, Loss G: 0.0273 , FID score : 90.5095
# [Epoch 38/50] Loss D: -0.0506, Loss G: 0.0274 , FID score : 92.3393
# [Epoch 39/50] Loss D: -0.0501, Loss G: 0.0270 , FID score : 91.3191
# [Epoch 40/50] Loss D: -0.0494, Loss G: 0.0267 , FID score : 91.5431
# [Epoch 41/50] Loss D: -0.0489, Loss G: 0.0264 , FID score : 90.4060
# [Epoch 42/50] Loss D: -0.0483, Loss G: 0.0261 , FID score : 94.5687
# [Epoch 43/50] Loss D: -0.0478, Loss G: 0.0260 , FID score : 90.6185
# [Epoch 44/50] Loss D: -0.0472, Loss G: 0.0256 , FID score : 88.3000
# [Epoch 45/50] Loss D: -0.0467, Loss G: 0.0256 , FID score : 88.9401
# [Epoch 46/50] Loss D: -0.0463, Loss G: 0.0254 , FID score : 89.3939
# [Epoch 47/50] Loss D: -0.0459, Loss G: 0.0248 , FID score : 87.0379
# [Epoch 48/50] Loss D: -0.0455, Loss G: 0.0249 , FID score : 88.5221
# [Epoch 49/50] Loss D: -0.0452, Loss G: 0.0247 , FID score : 88.4517
# [Epoch 50/50] Loss D: -0.0447, Loss G: 0.0243 , FID score : 88.5971

# %%
generator_3 = Generator(latent_dim).to(device)
critic_3 = Critic().to(device)
optimizer_g3 = optim.RMSprop(generator_3.parameters(), lr=2e-5)
optimizer_c3 = optim.RMSprop(critic_3.parameters(), lr=2e-5)


with torch.no_grad():
    noise = torch.randn(10, latent_dim).to(device)
    gen_imgs = generator_3(noise)

# Get real images for comparison
for imgs, _ in dataloader:
    real_imgs = imgs.to(device)
    break
print("Before Training...")
val = evaluate_fid(generator_3, dataloader, 5000 , 100 , latent_dim, device)
show_imgs(real_imgs, gen_imgs, n=10)
print(f" FID : {val}")
print("Training started...")

# Start training
fid_3 = train_WGAN(generator_3, critic_3, optimizer_g3, optimizer_c3, dataloader, device, latent_dim, n_critic , c , n_epochs , val)
# Out:
# Before Training...
#  FID : 430.27470354403727
# Training started...
# [Epoch 1/50] Loss D: -0.0664, Loss G: 0.0304 , FID score : 218.6489
# [Epoch 2/50] Loss D: -0.0733, Loss G: 0.0349 , FID score : 220.6394
# [Epoch 3/50] Loss D: -0.0592, Loss G: 0.0287 , FID score : 163.5910
# [Epoch 4/50] Loss D: -0.0548, Loss G: 0.0260 , FID score : 149.2672
# [Epoch 5/50] Loss D: -0.0560, Loss G: 0.0264 , FID score : 140.4921
# [Epoch 6/50] Loss D: -0.0591, Loss G: 0.0277 , FID score : 139.9818
# [Epoch 7/50] Loss D: -0.0609, Loss G: 0.0284 , FID score : 138.0309
# [Epoch 8/50] Loss D: -0.0621, Loss G: 0.0291 , FID score : 129.3308
# [Epoch 9/50] Loss D: -0.0625, Loss G: 0.0293 , FID score : 127.7280
# [Epoch 10/50] Loss D: -0.0615, Loss G: 0.0289 , FID score : 122.0132
# [Epoch 11/50] Loss D: -0.0582, Loss G: 0.0278 , FID score : 123.2351
# [Epoch 12/50] Loss D: -0.0557, Loss G: 0.0264 , FID score : 118.0452
# [Epoch 13/50] Loss D: -0.0532, Loss G: 0.0251 , FID score : 108.5675
# [Epoch 14/50] Loss D: -0.0512, Loss G: 0.0242 , FID score : 98.0281
# [Epoch 15/50] Loss D: -0.0499, Loss G: 0.0233 , FID score : 102.9188
# [Epoch 16/50] Loss D: -0.0494, Loss G: 0.0232 , FID score : 95.8058
# [Epoch 17/50] Loss D: -0.0492, Loss G: 0.0230 , FID score : 92.7913
# [Epoch 18/50] Loss D: -0.0491, Loss G: 0.0229 , FID score : 92.7123
# [Epoch 19/50] Loss D: -0.0490, Loss G: 0.0226 , FID score : 88.8732
# [Epoch 20/50] Loss D: -0.0486, Loss G: 0.0225 , FID score : 90.7958
# [Epoch 21/50] Loss D: -0.0479, Loss G: 0.0224 , FID score : 90.5553
# [Epoch 22/50] Loss D: -0.0470, Loss G: 0.0217 , FID score : 89.8175
# [Epoch 23/50] Loss D: -0.0459, Loss G: 0.0213 , FID score : 92.2391
# [Epoch 24/50] Loss D: -0.0447, Loss G: 0.0206 , FID score : 93.2990
# [Epoch 25/50] Loss D: -0.0439, Loss G: 0.0199 , FID score : 94.4075
# [Epoch 26/50] Loss D: -0.0430, Loss G: 0.0199 , FID score : 92.0468
# [Epoch 27/50] Loss D: -0.0424, Loss G: 0.0192 , FID score : 93.1648
# [Epoch 28/50] Loss D: -0.0417, Loss G: 0.0191 , FID score : 90.9764
# [Epoch 29/50] Loss D: -0.0410, Loss G: 0.0184 , FID score : 89.2245
# [Epoch 30/50] Loss D: -0.0404, Loss G: 0.0181 , FID score : 88.2683
# [Epoch 31/50] Loss D: -0.0398, Loss G: 0.0180 , FID score : 83.6958
# [Epoch 32/50] Loss D: -0.0392, Loss G: 0.0181 , FID score : 85.2085
# [Epoch 33/50] Loss D: -0.0387, Loss G: 0.0175 , FID score : 81.1110
# [Epoch 34/50] Loss D: -0.0382, Loss G: 0.0173 , FID score : 81.8862
# [Epoch 35/50] Loss D: -0.0377, Loss G: 0.0173 , FID score : 82.1566
# [Epoch 36/50] Loss D: -0.0372, Loss G: 0.0167 , FID score : 83.7621
# [Epoch 37/50] Loss D: -0.0368, Loss G: 0.0166 , FID score : 82.8382
# [Epoch 38/50] Loss D: -0.0363, Loss G: 0.0164 , FID score : 80.7096
# [Epoch 39/50] Loss D: -0.0358, Loss G: 0.0165 , FID score : 79.8864
# [Epoch 40/50] Loss D: -0.0355, Loss G: 0.0164 , FID score : 78.9787
# [Epoch 41/50] Loss D: -0.0350, Loss G: 0.0158 , FID score : 80.0097
# [Epoch 42/50] Loss D: -0.0345, Loss G: 0.0156 , FID score : 77.9789
# [Epoch 43/50] Loss D: -0.0341, Loss G: 0.0155 , FID score : 74.1911
# [Epoch 44/50] Loss D: -0.0337, Loss G: 0.0154 , FID score : 77.2532
# [Epoch 45/50] Loss D: -0.0334, Loss G: 0.0149 , FID score : 75.7313
# [Epoch 46/50] Loss D: -0.0330, Loss G: 0.0152 , FID score : 73.0531
# [Epoch 47/50] Loss D: -0.0326, Loss G: 0.0148 , FID score : 72.7719
# [Epoch 48/50] Loss D: -0.0324, Loss G: 0.0143 , FID score : 71.8594
# [Epoch 49/50] Loss D: -0.0319, Loss G: 0.0144 , FID score : 72.5376
# [Epoch 50/50] Loss D: -0.0316, Loss G: 0.0142 , FID score : 72.4264

# %%
import pickle
fid_old = pickle.load(open('fid_old.pkl', 'rb'))

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(fid_old ,label=' lr = 0.00005')
plt.plot(fid_1 ,label=' lr = 0.0001')
plt.plot(fid_2 ,label=' lr = 0.00001')
plt.plot(fid_3 ,label=' lr = 0.00002')
plt.xlabel("Epoch")
plt.ylabel("FID")
plt.title("Comparison between learning rates")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
fid_old_last15 = fid_old[35:]
fid_1_last15 = fid_1[35:]
fid_2_last15 = fid_2[35:]
fid_3_last15 = fid_3[35:]

# %%
plt.figure(figsize=(10, 5))
plt.plot(fid_old_last15 ,label=' lr = 0.00005')
plt.plot(fid_1_last15 ,label=' lr = 0.0001')
plt.plot(fid_2_last15 ,label=' lr = 0.00001')
plt.plot(fid_3_last15 ,label=' lr = 0.00002')
plt.xlabel("Epoch")
plt.ylabel("FID")
plt.title("Comparison between learning rates on last 15 epochs")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
